# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt 
import seaborn as sns
import warnings 
from  six.moves import urllib
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
import os

download_dir="./data/"

download_url="https://raw.githubusercontent.com/aravind-selvam/datasets-for-ML-projects/main/cardekho_dataset.csv"

os.makedirs(download_dir,exist_ok=True)

filename=os.path.basename(download_url)

download_file_path=os.path.join(download_dir,filename)

urllib.request.urlretrieve(download_url,download_file_path)

df=pd.read_csv(download_file_path,index_col=[0])

# %%
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15411 entries, 0 to 19543
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#         vehicle_age     km_driven       mileage        engine     max_power  \
# count  15411.000000  1.541100e+04  15411.000000  15411.000000  15411.000000
# mean       6.036338  5.561648e+04     19.701151   1486.057751    100.588254
# std        3.013291  5.161855e+04      4.171265    521.106696     42.972979
# min        0.000000  1.000000e+02      4.000000    793.000000     38.400000
# 25%        4.000000  3.000000e+04     17.000000   1197.000000     74.000000
# 50%        6.000000  5.000000e+04     19.670000   1248.000000     88.500000
# 75%        8.000000  7.000000e+04     22.700000   1582.000000    117.300000
# max       29.000000  3.800000e+06     33.540000   6592.000000    626.000000
#
#               seats  selling_price
# count  15411.000000   1.541100e+04
# mean       5.325482   7.749711e+05
# std        0.807628   8.941284e+05
# min        0.000000   4.000000e+04
# 25%        5.000000   3.850000e+05
# 50%        5.000000   5.560000e+05
# 75%        5.000000   8.250000e+05
# max        9.000000   3.950000e+07

# %%
num_feat=[x for x in df.columns if df[x].dtype!='O']
cat_feat=[x for x in df.columns if df[x].dtype=='O']

# %%
for col in cat_feat:
    print(df[col].value_counts(normalize=True)*100)
    print("-------------------------")
# Out:
# car_name
# Hyundai i20           5.878918
# Maruti Swift Dzire    5.775096
# Maruti Swift          5.067809
# Maruti Alto           5.048342
# Honda City            4.912076
#                         ...
# Mercedes-AMG C        0.006489
# Tata Altroz           0.006489
# Ferrari GTC4Lusso     0.006489
# Hyundai Aura          0.006489
# Force Gurkha          0.006489
# Name: proportion, Length: 121, dtype: float64
# -------------------------
# brand
# Maruti           32.392447
# Hyundai          19.349815
# Honda             9.635974
# Mahindra          6.560249
# Toyota            5.145675
# Ford              5.126209
# Volkswagen        4.023100
# Renault           3.478035
# BMW               2.848615
# Tata              2.790215
# Mercedes-Benz     2.186750
# Skoda             2.167283
# Audi              1.245863
# Datsun            1.103108
# Jaguar            0.382843
# Land Rover        0.330932
# Jeep              0.266044
# Kia               0.207644
# Porsche           0.136266
# Volvo             0.129777
# MG                0.123289
# Mini              0.110311
# Nissan            0.071378
# Lexus             0.064889
# Isuzu             0.051911
# Bentley           0.019467
# Maserati          0.012978
# ISUZU             0.012978
# Ferrari           0.006489
# Mercedes-AMG      0.006489
# Rolls-Royce       0.006489
# Force             0.006489
# Name: proportion, dtype: float64
# -------------------------
# model
# i20            5.878918
# Swift Dzire    5.775096
# Swift          5.067809
# Alto           5.048342
# City           4.912076
#                  ...
# Ghibli         0.006489
# Altroz         0.006489
# GTC4Lusso      0.006489
# Aura           0.006489
# Gurkha         0.006489
# Name: proportion, Length: 120, dtype: float64
# -------------------------
# seller_type
# Dealer              61.897346
# Individual          36.980079
# Trustmark Dealer     1.122575
# Name: proportion, dtype: float64
# -------------------------
# fuel_type
# Petrol      49.594446
# Diesel      48.140938
# CNG          1.953150
# LPG          0.285510
# Electric     0.025955
# Name: proportion, dtype: float64
# -------------------------
# transmission_type
# Manual       79.326455
# Automatic    20.673545
# Name: proportion, dtype: float64
# -------------------------

# %% [markdown]
# ## Univariate Analysis(one variable)

# %% [markdown]
#  We're doing this to study how the features are distributed

# %% [markdown]
# ## Numerical Data

# %%
# plt.figure(figsize=(15,15))
# plt.suptitle("Univarite Analysis of Numerical Features",fontsize=20,fontweight=10)

# for i in range(0,len(num_feat)):
#     plt.subplot(3,3,i+1)
#     sns.kdeplot(x=df[num_feat[i]],shade=True,color='b')
#     plt.xlabel(num_feat[i])
#     plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
plt.suptitle("Histplot with density",fontsize=20,fontweight=10)
for i , j in enumerate(num_feat):
    plt.subplot(3,3,i+1)
    sns.histplot(x=df[j],kde=True)
    sns.rugplot(x=df[j],height=.03,color='darkblue')
plt.tight_layout()

# %% [markdown]
# ## Interpretation
# 1)Most of them are right Skewed data , like Km_drives,max_power , selling_price and engine are positive and right skewed , Which is observed using the density and histograms.
# 2)And there are outliers in Km_driven , engine,selling_price and max power . Which is observed using the rugplot

# %%
plt.figure(figsize=(30,30))
plt.suptitle("Boxplot to confirm outliers",fontsize=20,fontweight=20)
for i,j in enumerate(num_feat):
    plt.subplot(3,3,i+1)
    sns.boxplot(x=df[j])
plt.tight_layout()

# %% [markdown]
# This confirms our previous interpretation of outliers in Km_driven , engine,selling_price and max power

# %%
plt.figure(figsize=(30,30))
plt.suptitle("Violin plot is a combination of both box plot and kde pl ",fontsize=20,fontweight=20)
for i,j in enumerate(num_feat):
    plt.subplot(3,3,i+1)
    sns.violinplot(x=df[j])
plt.tight_layout()

# %% [markdown]
# ## Categorical Values

# %%
df.describe(include='object')
# Out:
#            car_name   brand  model seller_type fuel_type transmission_type
# count         15411   15411  15411       15411     15411             15411
# unique          121      32    120           3         5                 2
# top     Hyundai i20  Maruti    i20      Dealer    Petrol            Manual
# freq            906    4992    906        9539      7643             12225

# %%
cat_feat
# Out:
# ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %%
#Have to fu=igure out why this does not work
# plt.figure(figsize=(20,20))
# plt.suptitle("Barplot for Categorical analysis")
# s_cat=['seller_type','fuel_type','transmisson_type']
# for i in range(0,len(s_cat)):
#     plt.subplot(3,1,i+1)
#     sns.countplot(x=df[s_cat[i]])
#     plt.xlabel(df[s_cat[i]])
#     plt.ylabel("count")
#     plt.xticks(rotation=45)
#     plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.countplot(x=df['seller_type'])
plt.subplot(1,2,2)
xx=df['seller_type'].value_counts()
plt.pie(xx,shadow=True,labels=df['seller_type'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x22e92688ca0>,
#   <matplotlib.patches.Wedge at 0x22e9232dca0>,
#   <matplotlib.patches.Wedge at 0x22e92696a00>],
#  [Text(-0.4016364722380601, 1.024054756430615, 'Individual'),
#   Text(0.36527911882672726, -1.0375794742327789, 'Dealer'),
#   Text(1.0993160098253516, -0.03878544239360547, 'Trustmark Dealer')])

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.countplot(x=df['fuel_type'])
plt.subplot(1,2,2)
xx=df['fuel_type'].value_counts()
plt.pie(xx,shadow=True,labels=df['fuel_type'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x22e926cf8e0>,
#   <matplotlib.patches.Wedge at 0x22e92688d00>,
#   <matplotlib.patches.Wedge at 0x22e92762580>,
#   <matplotlib.patches.Wedge at 0x22e92762c40>,
#   <matplotlib.patches.Wedge at 0x22e92771340>],
#  [Text(0.01401462881644176, 1.099910719185488, 'Petrol'),
#   Text(-0.09216643559023786, -1.0961319939453418, 'Diesel'),
#   Text(1.096399634656189, -0.08892604301201884, 'CNG'),
#   Text(1.099938195890643, -0.011660412550071848, 'LPG'),
#   Text(1.0999996341508393, -0.0008971443696368081, 'Electric')])

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.countplot(x=df['transmission_type'])
plt.subplot(1,2,2)
xx=df['transmission_type'].value_counts()
plt.pie(xx,shadow=True,labels=df['transmission_type'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x22e926fdf70>,
#   <matplotlib.patches.Wedge at 0x22e92a95910>],
#  [Text(-0.8760392145981636, 0.6652482953651464, 'Manual'),
#   Text(0.8760392457406824, -0.6652482543547908, 'Automatic')])

# %% [markdown]
# # Bivariate & Multivariate Analysis:
# ##### In here we will be looking into elationship between features in data most importantly with the target variable

# %%
df[num_feat].corr()
# Out:
#                vehicle_age  km_driven   mileage    engine  max_power  \
# vehicle_age       1.000000   0.333891 -0.257394  0.098965   0.005208
# km_driven         0.333891   1.000000 -0.105239  0.192885   0.044421
# mileage          -0.257394  -0.105239  1.000000 -0.632987  -0.533128
# engine            0.098965   0.192885 -0.632987  1.000000   0.807368
# max_power         0.005208   0.044421 -0.533128  0.807368   1.000000
# seats             0.030791   0.192830 -0.440280  0.551236   0.172257
# selling_price    -0.241851  -0.080030 -0.305549  0.585844   0.750236
#
#                   seats  selling_price
# vehicle_age    0.030791      -0.241851
# km_driven      0.192830      -0.080030
# mileage       -0.440280      -0.305549
# engine         0.551236       0.585844
# max_power      0.172257       0.750236
# seats          1.000000       0.115033
# selling_price  0.115033       1.000000

# %%
sns.heatmap(df[num_feat].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue="transmission_type")
